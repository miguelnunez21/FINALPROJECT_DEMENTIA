# %%
import pandas as pd
url='https://raw.githubusercontent.com/miguelnunez21/AA_dementia/main/ProyectoFinal.csv'



# Leer el dataset desde el archivo CSV
dem = pd.read_csv(url,delimiter=';')
dem.describe(include = 'all')
# Out:
#             smoking          age  gender  educationyears           EF  \
# count   2190.000000  2190.000000    2190     2190.000000  2190.000000
# unique          NaN          NaN       2             NaN          NaN
# top             NaN          NaN  female             NaN          NaN
# freq            NaN          NaN    1112             NaN          NaN
# mean       0.672146    67.147183     NaN       10.956849    -0.193582
# std        0.708430     9.062234     NaN        3.028129     0.801368
# min        0.000000    38.000000     NaN        1.000000    -5.200000
# 25%        0.000000    61.000000     NaN        9.000000    -0.610000
# 50%        1.000000    68.000000     NaN       10.000000    -0.070000
# 75%        1.000000    74.000000     NaN       13.000000     0.390000
# max        2.000000    90.000000     NaN       24.000000     2.350000
#
#                  PS       Global     diabetes hypertension  \
# count   2190.000000  2190.000000  2190.000000         2190
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Mostrar estadísticas antes de la estandarización
print("Estadísticas antes de la estandarización:")
print(dem.describe())

# Crear un objeto StandardScaler
scaler = StandardScaler()

# Copiar el DataFrame original
dem_standardized = dem.copy()

# Seleccionar todas las columnas numéricas para estandarizar
columns_to_standardize = dem_standardized.select_dtypes(include=['float64', 'int64']).columns

# Ajustar el scaler a las columnas seleccionadas y transformar los datos
# luego reemplazar las columnas originales con las estandarizadas
dem_standardized[columns_to_standardize] = scaler.fit_transform(dem_standardized[columns_to_standardize])

# Mostrar estadísticas después de la estandarización
print("\nEstadísticas después de la estandarización:")
print(dem_standardized.describe())
# Out:
# Estadísticas antes de la estandarización:
#            smoking          age  educationyears           EF           PS  \
# count  2190.000000  2190.000000     2190.000000  2190.000000  2190.000000
# mean      0.672146    67.147183       10.956849    -0.193582    -0.222350
# std       0.708430     9.062234        3.028129     0.801368     0.871702
# min       0.000000    38.000000        1.000000    -5.200000    -2.680000
# 25%       0.000000    61.000000        9.000000    -0.610000    -0.806667
# 50%       1.000000    68.000000       10.000000    -0.070000    -0.242508
# 75%       1.000000    74.000000       13.000000     0.390000     0.400000
# max       2.000000    90.000000       24.000000     2.350000     2.730000
#
#             Global     diabetes      Fazekas    lac_count  dementia_all
# count  2190.000000  2190.000000  2190.000000  2190.000000   2190.000000
# mean     -0.139076     0.145662     1.394521     0.587215      0.211872
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler


# Crear un objeto StandardScaler
scaler = StandardScaler()

# Copiar el DataFrame original
dem_standardized = dem.copy()

# Seleccionar todas las columnas numéricas para estandarizar
columns_to_standardize = dem_standardized.select_dtypes(include=['float64', 'int64']).columns

# Ajustar el scaler a las columnas seleccionadas y transformar los datos
# luego reemplazar las columnas originales con las estandarizadas
dem_standardized[columns_to_standardize] = scaler.fit_transform(dem_standardized[columns_to_standardize])


# Cambiar la configuración de pandas para mostrar todas las filas y columnas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Mostrar todos los valores del DataFrame original y estandarizado
print("\nValores del DataFrame original:")
print(dem)

print("\nValores del DataFrame estandarizado:")
print(dem_standardized)

# Restaurar la configuración original de pandas para evitar problemas de rendimiento
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# Valores del DataFrame original:
#       smoking        age  gender  educationyears        EF        PS  \
# 0           1  76.596851  female             8.0 -0.619906 -0.803036
# 1           1  76.596851  female             8.0 -0.619906 -0.803036
# 2           1  76.596851  female             8.0 -0.619906 -0.803036
# 3           1  76.596851  female             8.0 -0.619906 -0.803036
# 4           1  76.202601    male            10.0 -0.476078 -0.712535
# 5           1  76.202601    male            10.0 -0.476078 -0.712535
# 6           1  76.202601    male            10.0 -0.476078 -0.712535
# 7           1  76.202601    male            10.0 -0.476078 -0.712535
# 8           1  76.202601    male            10.0 -0.476078 -0.712535
# 9           1  76.202601    male            10.0 -0.476078 -0.712535
# 10          1  76.202601    male            10.0 -0.476078 -0.712535
# 11          1  76.202601    male            10.0 -0.476078 -0.712535
# ...

# %%
import pandas as pd 
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Crear un OneHotEncoder para la columna 'dementia_all'
onehot_encoder = OneHotEncoder(drop='first', sparse_output=False)

# Aplicar One-Hot Encoding a la columna 'dementia_all'
dementia_encoded = onehot_encoder.fit_transform(dem_standardized[['dementia_all']])

# Convertir a DataFrame para facilitar la visualización
dementia_encoded_df = pd.DataFrame(dementia_encoded, columns=onehot_encoder.get_feature_names_out(['dementia_all']))

# Crear un PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)

# Aplicar expansión polinómica
dementia_poly = poly.fit_transform(dementia_encoded_df)

# Convertir a DataFrame para facilitar la visualización
dementia_poly_df = pd.DataFrame(dementia_poly, columns=poly.get_feature_names_out(onehot_encoder.get_feature_names_out(['dementia_all'])))
# Tomar solo una de las nuevas columnas como la columna 'dementia_all' 
dementia_poly_df_single = dementia_poly_df.iloc[:, 0] # Usamos la primera columna

# Añadir la nueva columna 'dementia_all' al DataFrame original 
dem_standardized['dementia_all'] = dementia_poly_df_single

print (dem_standardized)





dem_standardized_encoded = pd.get_dummies(dem_standardized, drop_first=True)
print (dem_standardized_encoded)
# Out:
#        smoking       age  gender  educationyears        EF        PS  \
# 0     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 1     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 2     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 3     0.462895  1.042991  female       -0.976684 -0.532116 -0.666304
# 4     0.462895  0.999476    male       -0.316059 -0.352597 -0.562459
# ...        ...       ...     ...             ...       ...       ...
# 2185 -0.948999 -0.016245  female        0.674878  0.116805  0.232185
# 2186 -0.948999  0.425248  female        0.674878 -0.220196 -0.961155
# 2187  0.462895 -1.340724    male       -0.316059  0.815770  1.356679
# 2188  0.462895 -1.451098    male       -0.316059  0.478769  0.289557
# 2189  0.462895  0.094128  female       -0.316059  0.878177 -0.353011
#
#         Global  diabetes hypertension hypercholesterolemia   Fazekas  \
# ...

# %% [markdown]
# # K_NN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
import pandas as pd 
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures, StandardScaler 
from sklearn.model_selection import train_test_split, KFold, cross_val_score, cross_val_predict 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import confusion_matrix
# Separar características y etiquetas
X = dem_standardized_encoded.drop('dementia_all', axis=1)
y = dem_standardized_encoded['dementia_all']

# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors=4)  # You can adjust n_neighbors

# Perform 10-fold cross-validation
scores = cross_val_score(knn, X, y, cv=10, scoring='accuracy')

# Print mean and standard deviation of scores
print("Mean accuracy:", scores.mean())
print("Standard deviation:", scores.std())
# Out:
# Mean accuracy: 0.7712328767123288
# Standard deviation: 0.027125747470829496

# %% [markdown]
# # NEURAL NETWORK

# %%
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input 
from sklearn.model_selection import KFold

X = dem_standardized_encoded.drop('dementia_all', axis=1)
y = dem_standardized_encoded['dementia_all']


input_shape = X.shape[1]
# Define the number of folds for cross-validation

# Split the data into training and validation sets for the current fold
X_train, X_val = X.iloc[train_index], X.iloc[val_index]
y_train, y_val = y.iloc[train_index], y.iloc[val_index]

cost_matrix = np.array([[0, 10], [1, 0]])

def create_model():
# Create a sequential model
  model = Sequential([
    Input(shape =(input_shape,)),
    Dense(100, activation='relu'),
    Dense(100, activation='relu'),
    Dense(1, activation='sigmoid')
  ])
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
  return model


# Create a new model for each fold
model = create_model()

# Train the model on the training data
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
                               
history = model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=0, validation_data=(X_val, y_val), callbacks=[early_stopping]) # Set verbose to 0 to suppress output
y_pred_fold = (model.predict(X_test) > 0.5).astype("int32")
confusion_mat = confusion_matrix(y_test, y_pred_fold)
cost = np.sum(confusion_mat * np.transpose(cost_matrix))
accuracy = accuracy_score(y_test, y_pred_fold)

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 100], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
model = create_model()

    # Train the model on the training data
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
                                   
    history = model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=0, validation_data=(X_val, y_val), callbacks=[early_stopping]) # Set verbose to 0 to suppress output

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 100], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# # TRAINING DEEP NEURAL NETWORK

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures, StandardScaler
from sklearn.model_selection import KFold, cross_val_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from scikeras.wrappers import KerasClassifier
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt
from keras.initializers import GlorotNormal



tf.keras.utils.set_random_seed(42)

input_shape = X.shape[1]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
# Create a sequential model
model = Sequential([
  Input(shape =(input_shape,)),
  Dense(100, activation='relu', name='capa0'),
  Dense(100, activation='relu', name='capa1'),
  Dense(1, activation='sigmoid', name='capa2')
])
# Compile the model
optimizer = optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train the model with 100 epochs and batch size of 16

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.4)

# Evaluate the model. The method evaluate always returns the training loss, plus the
# additional metrics (accuracy in our case) that have been indicated.
# _ will be the loss; this is a typical throw away name for Python variable (it will be asigned the loss)
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7969 - loss: 0.5061 - val_accuracy: 0.8137 - val_loss: 0.3979
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8096 - loss: 0.4117 - val_accuracy: 0.8004 - val_loss: 0.3950
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8217 - loss: 0.4009 - val_accuracy: 0.8023 - val_loss: 0.3934
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8301 - loss: 0.3890 - val_accuracy: 0.8023 - val_loss: 0.3913
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8370 - loss: 0.3780 - val_accuracy: 0.8061 - val_loss: 0.3907
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8435 - loss: 0.3690 - val_accuracy: 0.8042 - val_loss: 0.3900
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8519 - loss: 0.3592 - val_accuracy: 0.7985 - val_loss: 0.3918
# Epoch 8/100
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, (y_test))
print(f"Test accuracy: {test_acc}")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8679 - loss: 0.8028
# Test accuracy: 0.8721461296081543

# %%
import matplotlib.pyplot as plt

# Plot losses and accuracies of each epoch
pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 100], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# # WEIGHT INITIALIZATION

# %% [markdown]
# # WEIGHT BEFORE

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Compilar el modelo
optimizer = optimizers.SGD(learning_rate=0.1)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]

# Graficar la diferencia entre los pesos antes y después del entrenamiento
plt.figure(figsize=(10, 6))
plt.bar(layer_names, diff_weights)
plt.xlabel("Layers")
plt.ylabel("Average Weight")
plt.title("Average Weight Change in Each Layer After Training")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9002 - loss: 0.5858 - val_accuracy: 0.8584 - val_loss: 0.3916
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9255 - loss: 0.2713 - val_accuracy: 0.8904 - val_loss: 0.3175
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9407 - loss: 0.1980 - val_accuracy: 0.8995 - val_loss: 0.2345
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9473 - loss: 0.1503 - val_accuracy: 0.9087 - val_loss: 0.1851
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9549 - loss: 0.1214 - val_accuracy: 0.9361 - val_loss: 0.1547
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9666 - loss: 0.1032 - val_accuracy: 0.9315 - val_loss: 0.1387
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9772 - loss: 0.0864 - val_accuracy: 0.9315 - val_loss: 0.1469
# Epoch 8/100
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()

# %% [markdown]
# # WI: NORMAL WITH HIGH STANDARD DEVIATION

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt
from keras.initializers import GlorotNormal

# Improper initialization of weights: normal with high standard deviation
def bad_weight_init(shape, dtype=None):
    return np.random.normal(loc=0.0, scale=0.1, size=shape)

tf.random.set_seed(42)

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))


model.add(Dense(100, activation='relu', kernel_initializer=bad_weight_init, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=bad_weight_init, name='dense_1')) # Segunda capa oculta 
model.add(Dense(1, activation='sigmoid', name='dense_2'))

# Compilar el modelo
optimizer = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7102 - loss: 0.6302 - val_accuracy: 0.8128 - val_loss: 0.4636
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8014 - loss: 0.4629 - val_accuracy: 0.8128 - val_loss: 0.3956
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8043 - loss: 0.4084 - val_accuracy: 0.8356 - val_loss: 0.3700
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8203 - loss: 0.3846 - val_accuracy: 0.8447 - val_loss: 0.3583
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8215 - loss: 0.3724 - val_accuracy: 0.8447 - val_loss: 0.3520
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8252 - loss: 0.3652 - val_accuracy: 0.8402 - val_loss: 0.3479
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8274 - loss: 0.3604 - val_accuracy: 0.8447 - val_loss: 0.3449
# Epoch 8/100
# ...

# %% [markdown]
# # GLOROT/XAVIER INITIALIZATION

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt
from keras.initializers import GlorotNormal

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = GlorotNormal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 
model.add(Dense(1, activation='sigmoid', name='dense_2'))

# Compilar el modelo
optimizer = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4960 - loss: 0.7259 - val_accuracy: 0.8219 - val_loss: 0.4366
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8068 - loss: 0.4392 - val_accuracy: 0.8311 - val_loss: 0.3847
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8191 - loss: 0.3959 - val_accuracy: 0.8265 - val_loss: 0.3658
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8206 - loss: 0.3769 - val_accuracy: 0.8493 - val_loss: 0.3564
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8280 - loss: 0.3666 - val_accuracy: 0.8402 - val_loss: 0.3509
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8328 - loss: 0.3602 - val_accuracy: 0.8447 - val_loss: 0.3472
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8355 - loss: 0.3558 - val_accuracy: 0.8402 - val_loss: 0.3443
# Epoch 8/100
# ...

# %% [markdown]
# # LECUN INITIALIZATION

# %%
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt
from keras.initializers import lecun_normal

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = lecun_normal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 
model.add(Dense(1, activation='sigmoid', name='dense_2'))

# Compilar el modelo
optimizer = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6446 - loss: 0.6011 - val_accuracy: 0.8219 - val_loss: 0.3902
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8153 - loss: 0.3954 - val_accuracy: 0.8311 - val_loss: 0.3679
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8237 - loss: 0.3748 - val_accuracy: 0.8265 - val_loss: 0.3581
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8331 - loss: 0.3647 - val_accuracy: 0.8219 - val_loss: 0.3516
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8373 - loss: 0.3580 - val_accuracy: 0.8265 - val_loss: 0.3465
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8413 - loss: 0.3528 - val_accuracy: 0.8356 - val_loss: 0.3423
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8465 - loss: 0.3485 - val_accuracy: 0.8402 - val_loss: 0.3388
# Epoch 8/100
# ...

# %% [markdown]
# # HE INITIALIZATION

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = HeNormal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 
model.add(Dense(1, activation='sigmoid', name='dense_2'))

# Compilar el modelo
optimizer = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6946 - loss: 0.6007 - val_accuracy: 0.8128 - val_loss: 0.3906
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8107 - loss: 0.3984 - val_accuracy: 0.8265 - val_loss: 0.3592
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8257 - loss: 0.3711 - val_accuracy: 0.8265 - val_loss: 0.3457
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8295 - loss: 0.3580 - val_accuracy: 0.8311 - val_loss: 0.3372
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8350 - loss: 0.3495 - val_accuracy: 0.8356 - val_loss: 0.3313
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8423 - loss: 0.3429 - val_accuracy: 0.8402 - val_loss: 0.3266
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8497 - loss: 0.3376 - val_accuracy: 0.8402 - val_loss: 0.3227
# Epoch 8/100
# ...

# %% [markdown]
# # Issues with the number of layers

# %% [markdown]
# # 1 hidden layer

# %%
# Define the neural network (same architecture as before)
model = Sequential()
model.add(Input(shape=(X_train.shape[1],)))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid')) 

# Compile the model
optimizer = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
optimizers.SGD(learning_rate=0.01)
# Train
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1.01])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7750 - loss: 0.6103 - val_accuracy: 0.8174 - val_loss: 0.4801
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8023 - loss: 0.4783 - val_accuracy: 0.8174 - val_loss: 0.4180
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8066 - loss: 0.4268 - val_accuracy: 0.8265 - val_loss: 0.3902
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8117 - loss: 0.4013 - val_accuracy: 0.8311 - val_loss: 0.3753
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8168 - loss: 0.3867 - val_accuracy: 0.8265 - val_loss: 0.3664
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8157 - loss: 0.3774 - val_accuracy: 0.8265 - val_loss: 0.3604
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8201 - loss: 0.3710 - val_accuracy: 0.8265 - val_loss: 0.3561
# Epoch 8/100
# ...

# %% [markdown]
# # 9 hidden layer

# %%
# Define the neural network (same architecture as before)
model = Sequential()
model.add(Input(shape=(X_train.shape[1],)))
model.add(Dense(100, activation='relu'))
for i in range(8):
  model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  

# Compile the model
optimizer = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1.01])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7301 - loss: 0.6577 - val_accuracy: 0.8219 - val_loss: 0.5564
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.5515 - val_accuracy: 0.8219 - val_loss: 0.4974
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.5095 - val_accuracy: 0.8219 - val_loss: 0.4730
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4916 - val_accuracy: 0.8219 - val_loss: 0.4595
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4791 - val_accuracy: 0.8219 - val_loss: 0.4467
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4646 - val_accuracy: 0.8219 - val_loss: 0.4307
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4456 - val_accuracy: 0.8219 - val_loss: 0.4099
# Epoch 8/100
# ...

# %% [markdown]
# # IMPORTANCE OF ACTIVATION FUNCTIONS

# %% [markdown]
# # SIGMOID

# %%
tf.keras.utils.set_random_seed(42)

input_shape = X.shape[1]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
# Create a sequential model
model = Sequential([
  Input(shape =(input_shape,)),
  Dense(100, activation='sigmoid',  name='capa0'),
  Dense(100, activation='sigmoid', name='capa1'),
  Dense(100, activation='sigmoid',  name='capa02'),
  Dense(100, activation='sigmoid', name='capa12'),
  Dense(100, activation='sigmoid',  name='capa01'),
  Dense(100, activation='sigmoid', name='capa13'),
  Dense(1, activation='sigmoid', name='capa244')
])
# Compile the model
optimizer = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])



# Train
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1.01])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6221 - loss: 0.6442 - val_accuracy: 0.8219 - val_loss: 0.4695
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4966 - val_accuracy: 0.8219 - val_loss: 0.4692
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8030 - loss: 0.4965 - val_accuracy: 0.8219 - val_loss: 0.4692
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4964 - val_accuracy: 0.8219 - val_loss: 0.4692
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4964 - val_accuracy: 0.8219 - val_loss: 0.4692
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4964 - val_accuracy: 0.8219 - val_loss: 0.4692
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.4964 - val_accuracy: 0.8219 - val_loss: 0.4692
# Epoch 8/100
# ...

# %% [markdown]
# # OPTIMIZERS

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = HeNormal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 

model.add(Dense(1, activation='sigmoid', name='dense_3'))

# Compilar el modelo
optimizer = optimizers.Adam()
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7290 - loss: 0.5294 - val_accuracy: 0.8311 - val_loss: 0.3334
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8297 - loss: 0.3502 - val_accuracy: 0.8493 - val_loss: 0.3171
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8484 - loss: 0.3247 - val_accuracy: 0.8493 - val_loss: 0.3059
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8593 - loss: 0.3070 - val_accuracy: 0.8584 - val_loss: 0.2953
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8719 - loss: 0.2914 - val_accuracy: 0.8630 - val_loss: 0.2860
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8793 - loss: 0.2775 - val_accuracy: 0.8721 - val_loss: 0.2759
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8926 - loss: 0.2654 - val_accuracy: 0.8767 - val_loss: 0.2641
# Epoch 8/100
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Compilar el modelo
optimizer = optimizers.SGD(learning_rate=0.1)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]

# Graficar la diferencia entre los pesos antes y después del entrenamiento
plt.figure(figsize=(10, 6))
plt.bar(layer_names, diff_weights)
plt.xlabel("Layers")
plt.ylabel("Average Weight")
plt.title("Average Weight Change in Each Layer After Training")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0052 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 7/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 8/100
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = HeNormal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 

model.add(Dense(1, activation='sigmoid', name='dense_3'))

# Compilar el modelo
optimizer = optimizers.Adam()
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7191 - loss: 0.5880 - val_accuracy: 0.8402 - val_loss: 0.3648
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8400 - loss: 0.3617 - val_accuracy: 0.8493 - val_loss: 0.3297
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8480 - loss: 0.3371 - val_accuracy: 0.8493 - val_loss: 0.3165
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8705 - loss: 0.3239 - val_accuracy: 0.8584 - val_loss: 0.3054
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8752 - loss: 0.3119 - val_accuracy: 0.8630 - val_loss: 0.2938
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8762 - loss: 0.3016 - val_accuracy: 0.8630 - val_loss: 0.2851
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8758 - loss: 0.2922 - val_accuracy: 0.8630 - val_loss: 0.2778
# Epoch 8/100
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.initializers import HeNormal
from keras import optimizers
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = HeNormal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 

model.add(Dense(1, activation='sigmoid', name='dense_3'))

# Compilar el modelo
optimizer = optimizers.Adam()
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Recoger los pesos después del entrenamiento
average_weights = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights.append(np.mean(np.abs(weights)))

# Verificar las diferencias en los pesos antes de graficar
diff_weights = [w1 - w2 for w1, w2 in zip(average_weights, average_weights_ini)]
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.ylim([0, 1])  # Set y-axis range for accuracy

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7848 - loss: 0.6428 - val_accuracy: 0.8082 - val_loss: 0.3801
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8070 - loss: 0.4056 - val_accuracy: 0.8311 - val_loss: 0.3600
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8281 - loss: 0.3755 - val_accuracy: 0.8402 - val_loss: 0.3390
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8519 - loss: 0.3469 - val_accuracy: 0.8493 - val_loss: 0.3237
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8656 - loss: 0.3361 - val_accuracy: 0.8493 - val_loss: 0.3139
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8641 - loss: 0.3244 - val_accuracy: 0.8493 - val_loss: 0.3057
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8680 - loss: 0.3167 - val_accuracy: 0.8447 - val_loss: 0.2985
# Epoch 8/100
# ...

# %% [markdown]
# # COST BASED EVALUATION DEEP LEARNING

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
np.array([[0, 5], [1, 0]])


# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = HeNormal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 

model.add(Dense(1, activation='sigmoid', name='dense_3'))

# Compilar el modelo
optimizer = optimizers.Adam()
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_val, y_val), callbacks=[early_stopping])

y_pred_fold = (model.predict(X_test) > 0.5).astype("int32")
confusion_mat = confusion_matrix(y_test, y_pred_fold)
cost = np.sum(confusion_mat * np.transpose(cost_matrix))
accuracy = accuracy_score(y_test, y_pred_fold)

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 100], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")
plt.show()
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8104 - loss: 0.4814 - val_accuracy: 0.8447 - val_loss: 0.3720
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8494 - loss: 0.3794 - val_accuracy: 0.8402 - val_loss: 0.3504
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8497 - loss: 0.3571 - val_accuracy: 0.8493 - val_loss: 0.3322
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8610 - loss: 0.3427 - val_accuracy: 0.8630 - val_loss: 0.3163
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8664 - loss: 0.3297 - val_accuracy: 0.8630 - val_loss: 0.3060
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8692 - loss: 0.3194 - val_accuracy: 0.8721 - val_loss: 0.2969
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8741 - loss: 0.3103 - val_accuracy: 0.8721 - val_loss: 0.2888
# Epoch 8/100
# ...

# %%
np.array([[0, 10], [1, 0]])

# Definir el input_shape correctamente
input_shape = X_train.shape[1:]

# Crear y compilar el modelo
model = Sequential()
model.add(Input(shape=input_shape))

# Añadir capas ocultas con inicialización de He
initializer = HeNormal()

model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_0')) # Primera capa oculta 
model.add(Dense(100, activation='relu', kernel_initializer=initializer, name='dense_1')) # Segunda capa oculta 

model.add(Dense(1, activation='sigmoid', name='dense_3'))

# Compilar el modelo
optimizer = optimizers.Adam()
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Recoger los pesos iniciales de cada capa (inicializados aleatoriamente) antes del entrenamiento
average_weights_ini = []
layer_names = []
for layer in model.layers:
    weights = layer.get_weights()
    if weights:
        layer_names.append(layer.name)
        weights = weights[0]  # Ignorar los sesgos (biases)
        average_weights_ini.append(np.mean(np.abs(weights)))

# Entrenar el modelo y guardar el historial
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_val, y_val), callbacks=[early_stopping])

y_pred_fold = (model.predict(X_test) > 0.5).astype("int32")
confusion_mat = confusion_matrix(y_test, y_pred_fold)
cost = np.sum(confusion_mat * np.transpose(cost_matrix))
accuracy = accuracy_score(y_test, y_pred_fold)

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 100], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")
plt.show()
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6030 - loss: 0.6637 - val_accuracy: 0.8311 - val_loss: 0.3912
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8199 - loss: 0.4020 - val_accuracy: 0.8356 - val_loss: 0.3592
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8391 - loss: 0.3600 - val_accuracy: 0.8311 - val_loss: 0.3467
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8505 - loss: 0.3494 - val_accuracy: 0.8584 - val_loss: 0.3335
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8645 - loss: 0.3379 - val_accuracy: 0.8630 - val_loss: 0.3232
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8752 - loss: 0.3281 - val_accuracy: 0.8813 - val_loss: 0.3154
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8775 - loss: 0.3208 - val_accuracy: 0.8813 - val_loss: 0.3088
# Epoch 8/100
# ...
